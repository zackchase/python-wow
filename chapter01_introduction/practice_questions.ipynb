# %% [markdown]
# # Practice Questions on Basics
#
# This notebook contains a bunch of questions aimed at verifying that you know things about literals, variables, strings, ints, floats, and booleans.
#
# ## Literals
#
# ### Q1 Identify the types of each of the following literals
# ```
# "apple"
# 1
# "1"
# 1.1
# False
# 1.0
# 1.1
# "1.0"
# True
# None
# ```
#
# ### Q2
#
# Add 1 line of code below each comment to perform the task specified in the comment.

# %%
x = "Miles"
y = "Smiles"

# Convert the text in `x` to all caps and print to screen

# Convert the text in `y` to all lowercase and print to screen

# Concatenate `x` and `y` and print the result to screen

# Concatenate `x` and `y` using `+`, adding one space between them and print to screen. 

# Perform the same task but using Python string formatting with `%`. 
#   See examples --- https://www.learnpython.org/en/String_Formatting

# %% [markdown]
# ## Variables
#
# 1. Create a variable called "my_string" and assign the value "Miles Davis (Vol. 2)" to it.
# 2. What do you expect to see if you call my_string.upper()?
# 3. We just called `.upper()` -- this is function associated with specific object. What is the term for such a function?
# 4. After calling `.upper()`, what is the value of the `my_string` variable?
# 5. Assign the value reference by `my_string` to a new variable called `new_string`. Now run `my_string = "Water Babies"`. Has the value of `new_string` changed? Why or why not?
#
#
# ## Casting
#
# 1. Create a variable called `x` and assign it the value 3.3
# 2. Create a variable called `y` and assign it the value `"4.2"`
# 4. What datatype is `x`? What data type is `y`?
# 3. Can you compose the two together with the `+`? Why or why not?
# 5. What do we need to do to, and to which variable, before we can concatenate the two values?
# 6. What do we need to do to, and to which variable, before we can *sum* the two values?
# 7. For each of the following, can we cast it to a string?
#  * "apple
#  * "4.5"
#  * 9.2
#  * 11
#  * 2.
# 8. For each of the following can we cast it to an int?
#  * 3.3
#  * 3
#  * "apple"
# 9. For each of the following can we cast it to a float?
#  * 3.3
#  * 3
#  * "apple"
#
#
# ## Arithmetic
#
# 1. Given an integer `x` and integer `y`, what is the type of `x+y`? `x-y`? `x*y`? `x/y`?
# 2. Why is type of the division operator different than that of its operands?
# 2. Python 2 and many older languages handle integer division differently, truncating the decimal portion of the result. How do we run older-style integer division in Python 3?
# 3. Write an expression to perform older-style int division dividing `9` by `25`.
# 4. Write an expression using just basic Python to raise 9 to the 5th power.
# 5. Do the same but using the `pow` function from the `math` library.
#
# ## Boolean logic
#
# 1. What are the two allowable Boolean literals?
# 2. Assume that `p` and `q` are Python variables taking Boolean values, write Python expressions corresponding to the following the following logic expressions
#  * $\neg p$
#  * $p$ AND $q$
#  * $p$ OR $q$
#  * $p$ XOR $q$
#  * $p$ NAND $q$
#
# ## General knowledge
# 1. What is a programming language?
# 2. What is the difference between a compiled and scripted language and which is Python 3?
# 3. What are some advantages and disadvantages (in general) of scripted vs compiled languages?
# 4. You write a Python program to generate a compiled C program. And you can write a C program that serves as a Python interpreter. Does that mean that all languages are the same? Why or why not?
